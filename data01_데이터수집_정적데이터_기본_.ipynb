# %% [markdown]
# ### 1. 크롤링(crawling), 스크래핑(scraping), 파싱(parsing)
#  - 크롤링(crawling) : 웹문서의 하이퍼링크를  타고 들어 가는 행위로 스파이더링(spidering)라고도 한다.
#  - 스크래핑(scraping) : 웹 사이트에서 원하는 정보를 추출하는 기술
#  - 파싱(parsing) : 추출한 정보를 분석하는 기술

# %% [markdown]
# 2. 웹 페이지 요청하기
# - urllib 패키지 : 파이썬에서 내장 모듈
# - requests 패키지 : 외부모듈
#
#
# 3. 외부 라이브러리
#    - 정적 : BeautifulSoup
#    - 동적 : Selenium
#
#
# 4. BeautifulSoup
#   - HTML과 XML 문서의 parsing을 하기 위한 python패키지이므로  이 라이브러리를 이용해 정보를 추출한다.
#   - https://www.crummy.com/software/BeautifulSoup/bs4/doc/
#   - https://beautiful-soup-4.readthedocs.io/en/latest/
#
#
# 5. Selenium
#  - 'Web Applicaton'의 테스트를 자동화하기 위한 도구이다.
#  - Selenium에서는 웹브라우저를 실행 시킨 후 클릭을 하거나, 텍스트를 입력하고, 지우는 등의 조작에 해당하는 메소드를 지원한다.
#  - 팝업을 닫아줘야만 정상적으로 화면을 볼 수 있는 웹 사이트도 있다.
#    그리고 사용하는 이유 중 가장 중요한게 바로 동적 페이지(JavaScript)로 제공하는 HTML인 경우이다.
#  - 크롤링하는 도구는 BeautifulSoup사용하지만 동적으로 제어해주는 도구는 Selenium을 사용한다.
#
#
#   - !pip install selenium
#   - https://www.selenium.dev/
#   - chromdriver.exe 다운로드 https://chromedriver.chromium.org/downloads
#
#
# 6. 크롤러(crawler)
#    - 자동으로 웹 페이지에 있는 정보를 수집하는 프로그램이다.
#    - 크롤러을 '봇', '로봇', '스파이더'라 한다.
#    - 구글 등의 검색 엔진은 봇 크롤러를 사용해 전 세계에 있는 웹페이지의 정보를 모아서 축적한다. 그리고 사용자가 키워드를 검색하면 축적된 방대한 정보에서 적당한 웹페이지를 찾아서 제공해 준다.

# %% [markdown]
# ### 2. urllib 모듈
# - URL문자열과 웹 요청에 관련된 모듈 5개 제공
#  - urllib.request : URL 문자열을 가지고 요청 기능 제공
#  - urllib.response : urllib 모듈에 의해 사용되는 응답 클래스들 제공
#  - urllib.parse : URL 문자열을 파싱하여 해석하는 기능 제공
#  - urllib.error : urllib.request에 의해 발생하는 예외 클래스 제공
#  - urllib.robotparser : robots.txt파일을 구문 분석하는 기능 제공
#
#
#    https://seo.tbwakorea.com/blog/robots-txt-complete-guide/

# %%
import urllib.request # uv add urllib
from urllib.request import urlopen

# %%
print(dir(urllib.request))
# Out:
# ['AbstractBasicAuthHandler', 'AbstractDigestAuthHandler', 'AbstractHTTPHandler', 'BaseHandler', 'CacheFTPHandler', 'ContentTooShortError', 'DataHandler', 'FTPHandler', 'FancyURLopener', 'FileHandler', 'HTTPBasicAuthHandler', 'HTTPCookieProcessor', 'HTTPDefaultErrorHandler', 'HTTPDigestAuthHandler', 'HTTPError', 'HTTPErrorProcessor', 'HTTPHandler', 'HTTPPasswordMgr', 'HTTPPasswordMgrWithDefaultRealm', 'HTTPPasswordMgrWithPriorAuth', 'HTTPRedirectHandler', 'HTTPSHandler', 'MAXFTPCACHE', 'OpenerDirector', 'ProxyBasicAuthHandler', 'ProxyDigestAuthHandler', 'ProxyHandler', 'Request', 'URLError', 'URLopener', 'UnknownHandler', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '__version__', '_cut_port_re', '_ftperrors', '_get_proxies', '_get_proxy_settings', '_have_ssl', '_localhost', '_noheaders', '_opener', '_parse_proxy', '_proxy_bypass_macosx_sysconf', '_proxy_bypass_winreg_override', '_randombytes', '_safe_gethostbyname', '_splitattr', '_splithost', '_splitpasswd', '_splitport', '_splitquery', '_splittag', '_splittype', '_splituser', '_splitvalue', '_thishost', '_to_bytes', '_url_tempfiles', 'addclosehook', 'addinfourl', 'base64', 'bisect', 'build_opener', 'contextlib', 'email', 'ftpcache', 'ftperrors', 'ftpwrapper', 'getproxies', 'getproxies_environment', 'getproxies_macosx_sysconf', 'hashlib', 'http', 'install_opener', 'io', 'localhost', 'noheaders', 'os', 'parse_http_list', 'parse_keqv_list', 'pathname2url', 'proxy_bypass', 'proxy_bypass_environment', 'proxy_bypass_macosx_sysconf', 'quote', 're', 'request_host', 'socket', 'ssl', 'string', 'sys', 'tempfile', 'thishost', 'time', 'unquote', 'unquote_to_bytes', 'unwrap', 'url2pathname', 'urlcleanup', 'urljoin', 'urlopen', 'urlparse', 'urlretrieve', 'urlsplit', 'urlunparse', 'warnings']

# %%
url = "https://www.daum.net"

html = urlopen(url)

print(html) # http.client.HTTPResponse
print("---------------")
print(dir(html))
print("---------------")
print(type(html)) # class 'http.client.HTTPResponse
print("---------------")
print(html.status) # 응답코드 200 (정상적으로 응답을 받음)
print("---------------")
print(html.info())
print("---------------")
print(html.readline())
print("---------------")
print(html.readlines())
print("---------------")
# Out:
# <http.client.HTTPResponse object at 0x10c062cb0>
# ---------------
# ['__abstractmethods__', '__class__', '__del__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_abc_impl', '_checkClosed', '_checkReadable', '_checkSeekable', '_checkWritable', '_check_close', '_close_conn', '_get_chunk_left', '_method', '_peek_chunked', '_read1_chunked', '_read_and_discard_trailer', '_read_chunked', '_read_next_chunk_size', '_read_status', '_readinto_chunked', '_safe_read', '_safe_readinto', 'begin', 'chunk_left', 'chunked', 'close', 'closed', 'code', 'debuglevel', 'detach', 'fileno', 'flush', 'fp', 'getcode', 'getheader', 'getheaders', 'geturl', 'headers', 'info', 'isatty', 'isclosed', 'length', 'msg', 'peek', 'read', 'read1', 'readable', 'readinto', 'readinto1', 'readline', 'readlines', 'reason', 'seek', 'seekable', 'status', 'tell', 'truncate', 'url', 'version', 'will_close', 'writable', 'write', 'writelines']
# ---------------
# <class 'http.client.HTTPResponse'>
# ---------------
# 200
# ---------------
# Date: Thu, 23 Jul 2026 03:27:20 GMT
# Content-Type: text/html
# Content-Length: 689782
# Connection: close
# Vary: Accept-Encoding
# Accept-Ranges: bytes
# Access-Control-Allow-Origin: *
# Vary: Accept-Encoding
# X-WCSS: dC1jb21tb24tYndjYWNoZTI5OmhpdDow
# nel: {"report_to":"kakao-nel","max_age":86400,"failure_fraction":1,"success_fraction":0.01}
# report-To: {"group":"kakao-nel","max_age":86400,"endpoints":[{"url":"https://nel.onkakao.net/upload/", "priority": 1}, {"url": "https://nel.edge4k.com/upload/", "priority": 2}]}
# Cache-Control: no-cache, no-store
# Pragma: no-cache
# Strict-Transport-Security: max-age=15724800
#
#
# ---------------
# b'<!doctype html>\n'
# ---------------
# [b'<html lang="ko">\n', b' <head>\n', b'  <meta charset="utf-8">\n', b'  <title>Daum</title>\n', b'  <meta http-equiv="x-ua-compatible" content="IE=edge">\n', b'  <meta property="og:url" content="https://www.daum.net/">\n', b'  <meta property="og:type" content="website">\n', b'  <meta property="og:title" content="Daum">\n', b'  <meta http-equiv="Pragma" content="no-cache">\n', b'  <meta http-equiv="Expires" content="-1">\n', b'  <meta name="referrer" content="origin">\n', b'  <meta name="viewport" content="width=device-width,minimum-scale=1,initial-scale=1">\n', b'  <meta property="og:image" content="https://t1.daumcdn.net/top/favicon/20260220/daum_og.png">\n', b'  <meta property="og:description" content="\xec\x9d\xb4\xec\x9a\xa9\xec\x9e\x90 \xec\x84\xa0\xed\x83\x9d\xea\xb6\x8c\xec\x9d\x84 \xea\xb0\x95\xed\x99\x94\xed\x95\x9c \xeb\x89\xb4\xec\x8a\xa4, \xec\x84\xb8\xec\x83\x81\xec\x9d\x98 \xeb\xaa\xa8\xeb\x93\xa0 \xec\xa0\x95\xeb\xb3\xb4\xeb\xa5\xbc \xec\x97\xb0\xea\xb2\xb0\xed\x95\x98\xeb\x8a\x94 \xea\xb2\x80\xec\x83\x89. Daum\xec\x97\x90\xec\x84\x9c \xeb\x82\x98\xec\x9d\x98 \xea\xb4\x80\xec\x8b\xac \xec\xbd\x98\xed\x85\x90\xec\xb8\xa0\xeb\xa5\xbc \xec\xa6\x90\xea\xb2\xa8\xeb\xb3\xb4\xec\x84\xb8\xec\x9a\x94.">\n', b'  <meta name="description" content="\xec\x9d\xb4\xec\x9a\xa9\xec\x9e\x90 \xec\x84\xa0\xed\x83\x9d\xea\xb6\x8c\xec\x9d\x84 \xea\xb0\x95\xed\x99\x94\xed\x95\x9c \xeb\x89\xb4\xec\x8a\xa4, \xec\x84\xb8\xec\x83\x81\xec\x9d\x98 \xeb\xaa\xa8\xeb\x93\xa0 \xec\xa0\x95\xeb\xb3\xb4\xeb\xa5\xbc \xec\x97\xb0\xea\xb2\xb0\xed\x95\x98\xeb\x8a\x94 \xea\xb2\x80\xec\x83\x89. Daum\xec\x97\x90\xec\x84\x9c \xeb\x82\x98\xec\x9d\x98 \xea\xb4\x80\xec\x8b\xac \xec\xbd\x98\xed\x85\x90\xec\xb8\xa0\xeb\xa5\xbc \xec\xa6\x90\xea\xb2\xa8\xeb\xb3\xb4\xec\x84\xb8\xec\x9a\x94.">\n', b'  <link href="https://t1.daumcdn.net/top/favicon/20260220/daum.ico" rel="shortcut icon">\n', b'  <meta name="referrer" content="origin">\n', b'  <link rel="search" type="application/opensearchdescription+xml" href="https://search.daum.net/OpenSearch.xml" title="\xeb\x8b\xa4\xec\x9d\x8c">\n', b'  <link rel="stylesheet" href="https://t1.daumcdn.net/top/static/font/pretendard/pretendard-dynamic-subset.min.css">\n', b'  <link rel="stylesheet" href="https://t1.daumcdn.net/top/daum/daum-pc/production/20260714_140108/common.css">\n', b'  <script src="https://search1.daumcdn.net/search/statics/common/js/fe/amado-workspace/pc/3.0.1/main.js"></script>\n', b'  <script src="https://t1.daumcdn.net/search/statics/common/js/fe/search-library-workspace/virtual-keyboard/1.2.0/main.js" defer></script>\n', b'  <script src="https://search1.daumcdn.net/search/statics/common/js/fe/search-library-workspace/trend-animation/1.0.1/main.js" defer></script>\n', b'  <script type="text/javascript" charset="UTF-8" src="https://t1.daumcdn.net/kas/static/na.min.js" defer></script>\n', b'  <script> window.gladsdk = window.gladsdk || { cmd: [] }; </script>\n', b'  <script async src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script>\n', b'  <script src="https://t1.kakaocdn.net/play/kamp/sdk/2.0.27/external.min.js"></script>\n', b'  <script src="https://t1.kakaocdn.net/play/kamp/sdk/2.0.27/kamp.min.js"></script>\n', b' </head>\n', b' <body>\n', b'  <script>\n', b'window.tiller = { "serverTime": 1784777240907};\n', b'window.tillerInitData={"frames":[{"name":"root","code":15,"nodeKey":null,"uiType":"ADDON","nodeType":"ROOT","position":1,"attributes":{},"children":[{"name":"root","code":15,"nodeKey":null,"uiType":"ADDON","nodeType":"ROOT","position":0,"attributes":{},"children":[{"name":"\xec\x98\xa4\xed\x94\x88 \xed\x8c\x9d\xec\x97\x85 - \xec\xbd\x94\xec\xb9\x98 \xeb\xa7\x88\xed\x81\xac","code":138,"nodeKey":null,"uiType":"WELCOME","nodeType":"SLOT","position":1,"attributes":{"birthday":{"jsUrl":"https://t1.daumcdn.net/top/promo/birthday/h/1741061799100/birthday.js","enabled":"1"},"coachmark":{"jsUrl":"https://t1.daumcdn.net/top/promo/coachmark/h/1713143608517/coachmark.js","enabled":"1"," ...
# ---------------

# %% [markdown]
# ### 3 requests 모듈
#  - Kenneth Reitz에 의해 개발된 파이썬 라이브러리이다.
#  - HTTP 프로토콜과 관련된 기능을 지원한다.
#  - anaconda에서는 site-package로 설치되어 있음
#  -만약에 필요하면  !pip install requests
#  - requests.request(method, url, **kwargs)에서 제공해주는 함수
#    - method : 요청 방식 지정(GET, POST, HEAD, PUT, DELETE, OPTIONS)
#    - url : 요청할 대상 URL 문자열 지정
#    - params : [선택적]요청시 전달 할  Query문자열 지정(딕셔너리, 튜플, 리스트, 바이트열 가능)
#    - data : [선택적]요청시 바디에 담아서 전달할 요청 파라미터 지정(딕셔너리, 튜플, 리스트, 바이트열 가능)
#    - json : [선택적] 요청시 바디에 담아서 전달할 json타입의 객체 지정
#    - auth : [선택적]인증처리(로그인)에 사용할 튜플 지정
#
#  - requests. request( )함수에 요청 방식을 지정하여 호출하는 것과 동일한 함수를 지원한다.
#     - requests.get(url, params=None, **kwargs)
#     - requests.post(url, data=None, json=None)
#     - requests.delete(url, **kwargs)
#
#  - requests.models.Response객체(응답객체)
#    - text
#        - 문자열 형식으로 응답 컨텐츠 추출
#        - 추출시 사용되는 문자셋은 'ISO-8859-1'이므로 'utf-8'이나 'euc-kr' 문자셋으로 작성된 콘텐츠 추출시 한글이 깨지는 현상 발생
#        - 추출전 응답되는 컨텐츠의 문자셋정보를 파악하여 Response객체의 encoding속성에 문자 셋 정보를 설정한 후 추출
#
#
#   - content
#       - 바이트열 형식으로 응답 콘텐츠 추출
#       - 응답 콘텐츠가 이미지와 같은 바이너리 형식은 경우 사용
#       - 한글이 들어간 문자열 형식인 경우 r.content.decode('utf-8')를 사용해서 디코드 해야함

# %% [markdown]
# ### 4. urllib  VS requests
# - urllib
#    - 인코딩하여 바이너리 형태로 데이터 전송
#    - 데이터 전달 방식에 따라 GET요청, POST요청을 구분
# - requests
#    - 딕셔너리 형태로 데이터 전송
#    - 요청메서드 (GET, POST)를 명시하여 요청

# %% [markdown]
# ### 5 BeautifulSoup
# - HTML 및 XML 파일에서 데이터를 추출하기 위한 파이썬 라이브러리이다.
# - 파이썬에서 기본적으로 제공하는 라이브러리가 아니므로 별도 설치가 필요하다.
#    - Anaconda에는 BeautifulSoup 패키지가 Site-package로 설치되어 있다.
#    - pip install beautifulSoup4
# - HTML 및 XML 파일의 내용을 읽을 때 다음 파서(Parser)를 이용한다.
#    - html.parser, lxml, lxml-xml, html5lib
#    - 파이썬이 내장하고 있는 파서 사용 가능
#    - 좀 더 성능이 좋은 파서를 추가로 설치하여 사용 가능
#    - 파서 라이브러리(Parser Library) 비교
#      ![parser](https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2Fc28GWb%2FbtqCtX7fBRN%2FnRwJ7DSP8dtjjBxGwfGv10%2Fimg.png)
#
# - HTML파싱
#   - BeautifulSoup의 메인 패키지인 bs 패키지에서 BeautifulSoup( )함수 임포트
#   - 파싱할 HTML문서와 파싱에 사용할 파서(구문분석기)를 지정하여 호출
#   - HTML 문서에 대한 파싱이 끝나면 트리 구조 형식으로 DOM 객체 생성
#
# - bs4.BeautifulSoup 객체의 태그 접근 방법
#   - HTML문서를 파싱하고 bs4.BeautifulSoup 객체생성
#   - <html>, <head>태그와 <body>태그는 제외하고 접근하려는 태그에 계층 구조를 적용
#   - 태그명을 (.)연산자와 함께 사용
#     - bs.태그명
#     - bs.태그명.태그명
#     - bs.태그명.태그명.태그명
#     - bs.html.body.h1
#
#
# - bs4.element.Tag 객체의 주요 속성과 메서드
#   - 태그명 속출
#      - bs.태그명.name
#   - 속성 속출
#     - bs.태그명['속성명']
#     - bs.태그명.attrs
#   - 콘텐츠 추출
#     - bs.태그명.string
#     - bs.태그명.text
#     - bs.태그명.contents
#     - bs.태그명.strings
#     - bs.태그명.get_text( )
#
# - 태그로 부터 다른 태그로 이동
#    - 부모 태그 추출
#      - bs.태그명.parent
#    - 자식 태그들 추출
#      - bs.태그명.children
#    - 형제 태그 추출
#      - bs.태그명.next_sibling
#      - bs.태그명.previous_sibling
#      - bs.태그명.next_siblings
#      - bs.태그명.previous_siblings
#    - 자손 태그들 속출
#      - bs.태그명.descendants
#
# - bs4.BeautifulSoup 객체의 주요 메서드
#    - HTML문서에 대한 파싱이 끝나고 생성된 트리 구조 형식의 DOM객체
#    - 태그 찾기 기능의 주요 메서드
#       - find_all( ) 4버전 => findAll()  3버전
#       - find( )
#       - select( )
#       - find_parents( ) 및 find_parent( )
#       - find_next_siblings( )및 find_next_sibling( )
#       - find_previous_siblings( ) 및 find_previous_sibling( )
#       - find_all_next( ) 및 find_next( )
#       - first_all_previous( ) 및 first_previous( )

# %% [markdown]
# - requests 공식문서
# https://requests.readthedocs.io/en/latest/

# %%
import requests # uv add request

print(dir(requests))
print(requests.__version__)
# Out:
# ['ConnectTimeout', 'ConnectionError', 'DependencyWarning', 'FileModeWarning', 'HTTPError', 'JSONDecodeError', 'NullHandler', 'PreparedRequest', 'ReadTimeout', 'Request', 'RequestException', 'RequestsDependencyWarning', 'Response', 'Session', 'Timeout', 'TooManyRedirects', 'URLRequired', '__all__', '__author__', '__author_email__', '__build__', '__builtins__', '__cached__', '__cake__', '__copyright__', '__description__', '__doc__', '__file__', '__license__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__title__', '__url__', '__version__', '_check_cryptography', '_internal_utils', '_types', 'adapters', 'annotations', 'api', 'auth', 'certs', 'chardet_version', 'charset_normalizer_version', 'check_compatibility', 'codes', 'compat', 'cookies', 'delete', 'exceptions', 'get', 'head', 'hooks', 'logging', 'models', 'options', 'packages', 'patch', 'post', 'put', 'request', 'session', 'sessions', 'ssl', 'status_codes', 'structures', 'urllib3', 'utils', 'warnings']
# 2.34.2

# %% [markdown]
# - BeautifulSoup 공식문서
# https://beautiful-soup-4.readthedocs.io/en/latest/#

# %%
import bs4

print(bs4)
print(bs4.__version__)
# Out:
# <module 'bs4' from '/Users/parkchanryong/Desktop/SK네트웍스/SKN_35/data-collection-workspace/.venv/lib/python3.12/site-packages/bs4/__init__.py'>
# 4.15.0

# %%
import requests
import bs4

url = "http://www.naver.com"
res = requests.get(url)

print(res) # Response [200]
print(type(res)) # class 'requests.models.Response
print(dir(res))
print(res.text)
print(type(res.text)) # class 'str'
# Out:
# <Response [200]>
# <class 'requests.models.Response'>
# ['__annotations__', '__attrs__', '__bool__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_content', '_content_consumed', '_next', 'apparent_encoding', 'close', 'connection', 'content', 'cookies', 'elapsed', 'encoding', 'headers', 'history', 'is_permanent_redirect', 'is_redirect', 'iter_content', 'iter_lines', 'json', 'links', 'next', 'ok', 'raise_for_status', 'raw', 'reason', 'request', 'status_code', 'text', 'url']
#    <!doctype html> <html lang="ko" class="fzoom"> <head> <meta charset="utf-8"> <meta name="Referrer" content="origin"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <title>NAVER</title> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="google-site-verification" content="uru5NJKa1Bfr5nv5AdQ26Qat7UrPU_02l-PIZRLzI-g"/> <link rel="shortcut icon" type="image/x-icon" href="/favicon.ico?1"> <link rel="apple-touch-icon-precomposed" href="https://s.pstatic.net/static/www/nFavicon96.png"/> <link rel="apple-touch-icon" sizes="114x114" href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png"/> <link rel="apple-touch-icon" href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png"/> <link rel="stylesheet" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_260611.css"> <link rel="canonical" href="https://www.naver.com/"> <link rel="alternate" media="only screen and (max-width: 767px)" href="https://m.naver.com/"> <script>window.gladsdk=window.gladsdk||{},window.gladsdk.cmd=window.gladsdk.cmd||[],window.ndpsdk=window.ndpsdk||{},window.ndpsdk.cmd=window.ndpsdk.cmd||[],window.ndpsdk.polyfill=window.ndpsdk.polyfill||{cmd:[]};var g_ssc="navertop.v5";window.nsc=g_ssc,window.nmain=window.nmain||{},window.nmain.jsOrigin="www"</script> <script>window.ntm=window.ntm||[]</script> <script async src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-loader.js"></script> <script async src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script> <script src="https://ssl.pstatic.net/tveta/libs/assets/js/pc/main/min/pc.veta.core.min.js" defer="defer"></script>  <script>
# window["EAGER-DATA"] = window["EAGER-DATA"] || {};
# window["EAGER-DATA"]["PC-MEDIA-WRAPPER"] = {"@type":"PC-MEDIA-CONTENTS-BLOCK","blocks":[{"@type":"BLOCK","blocks":[{"@type":"PC-NEWSSTAND-BLOCK","blocks":[{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"907","name":"경북매일신문","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/907.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/907.png"},"showThumbnailView":true,"showListView":true,"regDate":"20260723 11:55:11","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"908","name":"국방일보","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/908.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/908.png"},"showThumbnailView":true,"showListView":true,"regDate":"20260722 17:46:25","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"909","name":"기호일보","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/909.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/909.png"},"showThumbnailView":true,"showListView":true,"regDate":"20260723 12:11:30","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"353","name":"중앙SUNDAY","logoLight":{"url":"https://s.pstatic.net/static/newsstand/up/2025/0418/nsd181433494.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/up/2025/0418/nsd181453897.png"},"showThumbnailView":true,"showListView":true,"regDate":"20260722 16:23:39","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"354","name":"엘르","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/354.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/354.png"},"showThumbnailView":true,"showListView":true,"regDate":"20260723 12:20:18","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"355","name":"사이언스타임즈","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/355.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/355.png"},"showThumbnailView":true,"showListView":true,"regDate":"20260723 09:03:27","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"356","name":"게임메카","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/356.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/356.png"},"showThumbnailView":true,"showListView":true,"regDate":"20260723 11:53:11","_id":null,"@type":"PC-N ...
# window["EAGER-DATA"]["PC-NEWSSTAND-YONHAP"] = {"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":null,"materials":[],"excludeInPaging":false,"positionForPaging":0,"realtime":false,"_id":null,"@type":"BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null}],"materials":[{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"李대통령 \"똘똘한 한채, 심각한 문제…주거·투기 구분않은 탓\"","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0016210733","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":null},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"관리규약 회의가 참사로…아파트 관리실 방화 폭발, 8명 부상","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0016210643","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":null},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"투표율 틀리자 수정 않고 통계 조작…6·3선거 사태 '새 국면'","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0016209886","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":null},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"삼성전자 노조, 특별성과급 사회공헌 추진…회사도 기부금 매칭","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0016210463","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":null},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"우리 국민 기대수명 83.7년, OECD 상위권…자살률은 여전히 1위","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0016210679","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":null},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"졸업 후 1년 이상 청년 백수 48.6%, 금융위기 이후 최고","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0016210681","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":null},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"정부 \"올해 3% 성장 가능성 커져…1인 GNI 4만달러는 지켜봐야\"","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0016210405","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":null},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"종합특검, 원희룡 전 국토장관 소환…'양평고속도로 의혹' 첫 조사","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0016210011","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":null},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"美국무 \"호르무즈 해군자산 기여하면 韓 등 아시아 동맹에 이익\"","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0016209520","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":null}],"excludeInPaging":false,"positionForPaging":0,"realtime":false,"_id":"6a33a786ddb0f515631cb6f7","@type":"BLOCK","@code":"PC-NEWSSTAND-YONHAP","@template":"PC-NEWSSTAND-YONHAP","@flowId":"PC-YONHAP","@flowExecutionId":"08edc97c-8646-11f1-a373-75f9998e8b9f","@provid ...
# window["EAGER-DATA"]["PC-PREMIUM-AD"] = {"@type":"PC-PREMIUM-AD-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"adResponse":{"type":"N010","adlineId":null,"vimp100p0s":null,"assets":null,"vimp50p1s":"https://siape.veta.naver.com/fxview?eu=EU10044434&calp=-&oj=UDLDkoMX9MNQsbHfqBkowlO16IB%2BSv5IzAMbLwc4DkdQpEVYxuJw1CGNcbrnFmKn&ac=8206821&src=4733402&evtcd=V900&x_ti=1362&tb=&oid=&sid1=&sid2=&rk=RbT27BS1YE4q10UpL2CvZg&eltts=ghqCrV0Nmdgvr1oK0dRHnw%3D%3D&brs=Y&&eid=V900"},"_id":null,"@type":null,"@code":"PC-PREMIUM-AD","@template":"PC-PREMIUM-AD","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null}
# window["EAGER-DATA"]["PC-MYSERVICE-META"] = {"@type":"PC-MYSREVICE-META","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"serviceMetaList":[],"_id":"6a33a824ddb0f515631ff432","@type":"MY-SERVICE-META-BLOCK","@code":"PC-MYSERVICE-META","@template":"NONE","@flowId":"PC-MYSERVICE-META","@flowExecutionId":"fbd03e50-8645-11f1-9d00-d1bb41e00637","@provider":"lambda","@lastModifiedAt":[2026,7,23,3,24,16,116000000]}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-MEDIA-TAB-EVENT"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"6a33a809ddb0f515631f7609","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-MEDIA-TAB-EVENT","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"ebbb93a9-8645-11f1-a373-d106780d6290","@provider":"lambda","@lastModifiedAt":[2026,7,23,3,23,49,143000000]}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-MID-BANNER"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"6a33a7bbddb0f515631db309","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-MID-BANNER","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"04c7517c-8646-11f1-9d00-556f1703cd34","@provider":"lambda","@lastModifiedAt":[2026,7,23,3,24,31,161000000]}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-TAB-META"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[{"content":{"@type":"BLOCK-PC-TAB-META","tabList":[{"weight":1,"useFeedCasEditTemplate":false,"enabled":true,"contingencyEnabled":true,"id":"PC-FEED-RECOMMEND","name":"추천・구독","clickCode":"tct.mynr"},{"weight":1,"useFeedCasEditTemplate":true,"enabled":true,"contingencyEnabled":true,"id":"PC-FEED-CARGAME","name":"자동차","clickCode":"tct.wtn"},{"weight":1,"useFeedCasEditTemplate":true,"enabled":true,"contingencyEnabled":true,"id":"PC-FEED-WEBTOON","name":"웹툰","clickCode":"tct.wtn"},{"weight":1,"useFeedCasEditTemplate":false,"enabled":true,"contingencyEnabled":true,"id":"PC-FEED-BEAUTY","name":"패션뷰티","clickCode":"tct.bty"},{"weight":1,"useFeedCasEditTemplate":false,"enabled":false,"contingencyEnabled":false,"id":"PC-FEED-RECIPE","name":"레시피","clickCode":"tct.fod"},{"weight":1,"useFeedCasEditTemplate":true,"enabled":true,"contingencyEnabled":true,"id":"PC-FEED-LIVINGHOME","name":"리빙","clickCode":"tct.lif"},{"weight":1,"useFeedCasEditTemplate":true,"enabled":true,"contingencyEnabled":true,"id":"PC-FEED-CULTURE","name":"책방","clickCode":"tct.bok"},{"weight":1,"useFeedCasEditTemplate":true,"enabled":true,"contingencyEnabled":true,"id":"PC-FEED-LECTURE","name":"지식+","clickCode":"tct.lec"},{"weight":1,"useFeedCasEditTemplate":false,"enabled":true,"contingencyEnabled":true,"id":"PC-FEED-HEALTH","name":"건강","clickCode":"tct.health"},{"weight":1,"useFeedCasEditTemplate":false,"enabled":false,"contingencyEnabled":false,"id":"PC-FEED-GAMEAPP","name":"게임","clickCode":"tct.gameapp"}],"area":"FEED"},"exposure":true,"@miniContentId":"643e64d370a065058f369bac","@miniContentCode":"PC-TAB-META","@startAt":"2023-04-10 00:00","@endAt":"2030-05-30 23:59","@createdAt":"2023-04-18T18:37:23.412","@updatedAt":"2026-06-17T11:05:50.081"},{"content":{"@type":"BLOCK-PC-TAB-META","tabList":[{"weight":1,"useFeedCasEditTemplate":false,"enabled":true,"contingencyEnabled":true,"id":"PC-MEDIA-NEWSSTAND","name":"뉴스스탠드","clickCode":"nst.nsd"},{"weight":1,"useFeedCasEditTemplate":false,"enabled":true,"contingencyEnabled":true,"id":"PC-MEDIA-NEWS","name":"언론사편집","clickCode":"nst.nch"},{"weight":1,"useFeedCasEditTemplate":false,"enabled":true,"contingencyEnabled":true,"id":"PC-MEDIA-ENTER","name":"엔터","clickCode":"nst.ent"},{"weight":1,"useFeedCasEditTemplate":false,"enabled":true,"contingencyEnabled":true,"id":"PC-MEDIA-SPORTS","name":"스포츠","clickCode":"nst.spo"},{"weight":1,"useFeedCasEditTemplate":false,"enabled":true,"contingencyEnabled":true,"id":"PC-MEDIA-ECONOMIC","name":"경제","clickCode":"nst.fin"},{"weight":1,"useFeedCasEditTemplate":false,"enabled":true,"contingencyEnabled":true,"id":"PC-MEDIA-SHOPPING-TODAY","name":"쇼핑투데이","clickCode":"nst.shpt"},{"weight":1,"useFeedCasEditTemplate":false,"enabled":true,"contingencyEnabled":true,"id":"PC-MEDIA-GAME","name":"게임","clickCode":"nst.game"}],"area":"MEDIA"},"exposure":true,"@miniContentId":"643e642c8793487c84743a38","@miniContentCode":"PC-TAB-META","@startAt":"2023-04-11 00:00","@endAt":"2030-05-31 23:59","@createdAt":"2023-04-18T18:34:36.648","@updatedAt":"2026-04-23T18:08:56.038"}],"_id":"6a33a71ebabf6de0cd65dd30","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-TAB-META","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"ee2cbaa4-8645-11f1-aebf-b98bb9a430c3","@provider":"lambda","@lastModifiedAt":[2026,7,23,3,23,53,240000000]}
# window["EAGER-DATA"]["PC-FEED-WRAPPER"] = {"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":null,"materials":[{"@type":"MATERIAL-PC-FEED","title":"무좀을 오래 방치하면 발톱이 두꺼워질 뿐 아니라 안쪽이 들뜨고 죽은 발톱으로 변하는 경우가 있습니다.  이번 고객님도 발톱 안쪽이 박리되어 있어 죽은 부분만 안전하게 제거한 뒤 스케일링을 진행했습니다.  혼자 뜯거나 깎기보다는 현재 발톱 상태를 정확히 확인하고 관리받는 것이 중요합니다.  무좀발톱, 두꺼운발톱, 들뜬발톱으로 고민이라면 초기에 관리할수록 더 ","url":"https://m.blog.naver.com/refuss-gimpo/clip/15278292","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Ftvcast.phinf%2F20260718_9%2FXjA1f_1784340673338PDush_JPEG%2Fthumbnail-BAA032A9-5AA6-447C-8AA9-BAC7BF425557.jpg%22&type=ff364_236&service=navermain"},"source":{"url":"https://clip.naver.com/@footory_park","name":"레푸스김포한강신도시","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fclip-service-phinf.pstatic.net%2FMjAyNTEyMjdfMTM0%2FMDAxNzY2ODI5MDg0NjI0.X4728QdR-JlM5EobRqwO-wfgCv1Z2Qjch10RvCiB8_Eg.hWbYXC_JZ2qQLreBpto_JWspbac27AnSaJWua0Hg3Dsg.PNG%2FKakaoTalk_20231116_152714693.png%22&type=nf40_40&service=navermain"}},"video":{"playTime":"00:17"},"showLiveBadge":false},{"@type":"MATERIAL-PC-FEED","title":"니삭스와 자전거 한대로 화보가 됐습니다 윈터가 입은 여름 데일리룩","url":"https://in.naver.com/kwanwoo0427/contents/internal/976154815355616","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22http%3A%2F%2Fblogfiles.naver.net%2FMjAyNjA3MjFfODUg%2FMDAxNzg0NjE4OTE3NjYz.m2-7nvdH0-IqWtq9thh2jugn2USbSG1Hm3VRlbGpNUog.0leQhh76u58D-u2WVBwAM5eVU6Z_kofKRWcIZfvA9u4g.JPEG%2F06.jpg%22&type=ff364_236&service=navermain"},"source":{"url":"https://blog.naver.com/wrng_stylenote","name":"우렁이 아카이브","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22http%3A%2F%2Fblogpfthumb.phinf.naver.net%2FMjAyNjAzMDZfMTgx%2FMDAxNzcyODA4NjIxMTk3.tb-a71wYI-2KxIKnt8w48cMv3XPGXftNep93Ds4e6egg.0hRmOr7IdGitiSMshDXO2Yk2aMejTA-hQvVCj37n9BIg.JPEG%2F%25EC%259A%25B0%25EB%25A0%2581%25EC%259D%25B4%25EC%258A%25A4%25ED%2583%2580%25EC%259D%25BC%25EB%2585%25B8%25ED%258A%25B8.jpg%2F%25EC%259A%25B0%25EB%25A0%2581%25EC%259D%25B4%25EC%258A%25A4%25ED%2583%2580%25EC%259D%25BC%25EB%2585%25B8%25ED%258A%25B8.jpg%22&type=nf40_40&service=navermain"}},"showLiveBadge":false},{"@type":"MATERIAL-PC-FEED","title":"롤렉스 데잇 저스트 31 성골 후기","url":"https://cafe.naver.com/parisienlook/5897331?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1haXJz.eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiYXJ0aWNsZUlkIjo1ODk3MzMxLCJjYWZlVXJsIjoicGFyaXNpZW5sb29rIiwiaXNzdWVkQXQiOjE3ODQ3NzY4MzczOTd9.xxO31sn_z34xYMlFfCSGTwM-ZUZSUDb2mGkbKHYcBz4","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fcafeptthumb-phinf.pstatic.net%2FMjAyNjA3MjJfMjI1%2FMDAxNzg0NzEyNTIyODc4.E03JfxiNbzMtpSQaWBPpRtF7c4gt81TKX9btl4Beduwg.D9TT3C3eGXi9_89E3iyYNM068IlYXwgk7m1TKbgYGEEg.JPEG%2FKakaoTalk_20260722_175240003_09.jpg%7C800x1066%22&type=ff364_236&service=navermain"},"source":{"url":"https://cafe.naver.com/parisienlook","name":"시크먼트 명품, 패션 커뮤니티 [샤넬 에르메스 반클리프 롤렉스]","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fcafeptthumb-phinf.pstatic.net%2FMjAyNDA4MDdfMTI5%2FMDAxNzIzMDE4MzQ2MTM2.9vi0cCb7bDXETM1yHEy1Syjlaommpjcq5vBJ6dx62CQg.GBAHwpTsN1cqq1jtPzpIWZ32Mp9_tbacMfgK2OKolSUg.PNG%2FImageChicmentCafeLogo.png%3Ftype%3Df40_40_mask%22&type=nf40_40&service=navermain"}},"showLiveBadge":false},{"@type":"MATERIAL-PC-FEED","title":"선크림 이중세안 피부 망치는 지름길? #피부관리 #선크림 #이중세안","url":"https://m.naver.com/shorts?serviceType=CLIP&mediaType=VOD&seedMediaId=038B2E7382B7F97D153EE4072632A822E714&recType=CLIP_PC&recId=%7B%22targetProfileId%22%3A%22JSTrhNQZbTUZFlaW4mve%22%2C%22open%22%3Atrue%7D","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fclip-service-phinf.pstatic.net%2FMjAyNjA3MjFfMjkz%2FMDAxNzg0NjI2NTkzOTQx.PTFTCEvtu497vTgFvIOLcf8b9H4OeuHCxLpRePtjfJcg.6qoc3AJ9ziHcbv21slxqkp9KtwUQREZyLZbQgiRf_DAg.JPEG%2Fthumbnail-3ADEF7E1-D86B-4FBB-AAC5-13927C399C0E.jpg%22&type=ff364_236&service=navermain"},"source":{"url":"https://clip.naver.com/@drleesangwook","name":"동네 의사 이상욱","imag ...
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-WHALE-BANNER-BOTTOM"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[{"content":{"banners":[{"url":"https://whale.naver.com/ko/?download=1&wpid=vertical4_theme1","image":"https://s.pstatic.net/static/www/mobile/edit/20260721_1095/upload_1784644679089SMkfa.png","mainCopy":"브라우저를 업데이트하세요","subCopy":"최신 기술을 품은 네이버 웨일에서 빠른 인터넷을 만나보세요"},{"url":"https://whale.naver.com/ko/?download=1&wpid=vertical4_theme2","image":"https://s.pstatic.net/static/www/mobile/edit/20260721_1095/upload_1784644698227MnGqS.png","mainCopy":"최신 브라우저 설치하기","subCopy":"네이버의 기술이 적용된 웨일 브라우저를 만나보세요"},{"url":"https://whale.naver.com/ko/?download=1&wpid=vertical4_theme3","image":"https://s.pstatic.net/static/www/mobile/edit/20260721_1095/upload_1784644728300XXiBj.png","mainCopy":"네이버 권장 브라우저","subCopy":"웨일 브라우저에서 네이버 서비스를 가장 편하게 사용하세요"},{"url":"https://whale.naver.com/ko/?download=1&wpid=vertical4_theme4","image":"https://s.pstatic.net/static/www/mobile/edit/20260721_1095/upload_1784644779198hYyo9.png","mainCopy":"안전한 브라우저 설정하기","subCopy":"나의 개인정보를 보호하는 웨일 브라우저를 지금 설치하세요"}],"title":"웨일 우하단 배너_롤링_최적화및단순화_13일차_19일차"},"exposure":true,"@miniContentId":"6a5f88e97d58db0659c2f8db","@miniContentCode":"PC-WHALE-BANNER-BOTTOM","@startAt":"2026-07-22 00:00","@endAt":"2026-07-28 23:59","@createdAt":"2026-07-21T23:57:45.465","@updatedAt":"2026-07-22T17:45:56.675"}],"_id":"6a4f4e60ddb0f515638048dc","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-WHALE-BANNER-BOTTOM","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"e8e234d9-8645-11f1-89a8-114f8b555f6f","@provider":"lambda","@lastModifiedAt":[2026,7,23,3,23,44,370000000]}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-SPECIAL-LOGO"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"6a33a787babf6de0cd68a327","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-SPECIAL-LOGO","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"511d3f7e-8646-11f1-aebf-635849917a94","@provider":"lambda","@lastModifiedAt":[2026,7,23,3,26,39,245000000]}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-WHALE-BANNER"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[{"content":{"phrases":[{"normalText":"현재 PC에 최적화된 브라우저","boldText":"웨일을 설치하세요","landingUrl":"https://whale.naver.com/ko/?download=1&wpid=main_theme1"},{"normalText":"네이버 공식 브라우저","boldText":"웨일을 설치하세요","landingUrl":"https://whale.naver.com/ko/?download=1&wpid=main_theme2"},{"normalText":"안전한 인터넷을 위한 브라우저","boldText":"웨일을 설치하세요","landingUrl":"https://whale.naver.com/ko/?download=1&wpid=main_theme3"}],"title":"웨일 PC상단배너 다양화_77일차_다운로드 플로우 개선_최적화및단순화2"},"exposure":true,"@miniContentId":"6a608271a85afb5d41c7d08b","@miniContentCode":"PC-WHALE-BANNER","@startAt":"2026-07-23 00:00","@endAt":"2026-07-23 23:59","@createdAt":"2026-07-22T17:42:25.222","@updatedAt":"2026-07-22T17:42:25.222"}],"_id":"6a33a764ddb0f515631be4f6","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-WHALE-BANNER","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"f4adc4b3-8645-11f1-aebf-25a74a6bed9f","@provider":"lambda","@lastModifiedAt":[2026,7,23,3,24,4,155000000]}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-SEARCH-RIGHT"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"6a33a785babf6de0cd68903c","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-SEARCH-RIGHT","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"08542239-8646-11f1-bd32-3142e69b4c2a","@provider":"lambda","@lastModifiedAt":[2026,7,23,3,24,37,119000000]}
# window["EAGER-DATA"]["PC-HEADLINE-AD"] = {"@type":"PC-HEADLINE-AD-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"adResponse":{"type":"N402","adlineId":"3141819","vimp100p0s":"https://siape.veta.naver.com/fxview?eu=EU10044129&calp=-&oj=ZJlEFeSBKmLf40n3ktJ9%2FFO16IB%2BSv5IzAMbLwc4DkdQpEVYxuJw1CGNcbrnFmKn&ac=9304198&src=8169511&evtcd=V900&x_ti=1587&tb=&oid=&sid1=&sid2=&rk=8D4lBIkxoVgiLQryoC9EOQ&eltts=ghqCrV0Nmdgvr1oK0dRHnw%3D%3D&brs=Y&&eid=V900","assets":{"hl_web_img":{"url":"https://ssl.pstatic.net/melona/libs/1570/1570613/d6247b239497b1e9dd9d_20260703063749275.png","alt":"[광고]7월의 리워드가 도착했어요 최대 3만P","w":488,"h":216},"hl_web_img_dark":{"url":"https://ssl.pstatic.net/melona/libs/1570/1570613/0979202520ab2bfc744a_20260703063753024.png","alt":"[광고]7월의 리워드가 도착했어요 최대 3만P","w":488,"h":216},"hl_link":{"url":"https://siape.veta.naver.com/fxclick?eu=EU10044129&calp=-&oj=ZJlEFeSBKmLf40n3ktJ9%2FFO16IB%2BSv5IzAMbLwc4DkdQpEVYxuJw1CGNcbrnFmKn&ac=9304198&src=8169511&br=4959198&evtcd=P901&x_ti=1587&tb=&oid=&sid1=&sid2=&rk=8D4lBIkxoVgiLQryoC9EOQ&eltts=ghqCrV0Nmdgvr1oK0dRHnw%3D%3D&brs=Y&&a=...","clicktracking":"https://ssl.pstatic.net/tveta/libs/1by1.gif"},"bb_web_img":null,"bb_web_img_dark":null,"bb_link":null,"bb_web_text":null}},"_id":null,"@type":null,"@code":"PC-HEADLINE-AD","@template":"PC-HEADLINE-AD","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null}
# </script>
#
# <script>
# window["ELECTION-DATA"] = window["ELECTION-DATA"] || {};
# window["ELECTION-DATA"] = {"noElectionData": true}
# </script>
#
#  <script>!function(){var e=Math.random()<1;const n={"s.pstatic.net":"s.naver.net","pm.pstatic.net":"pm.naver.net","mm.pstatic.net":"mm.naver.net","mml.pstatic.net":"mml.naver.net","ssl.pstatic.net":"sstatic.naver.net"},t=["ssl.pstatic.net"];window.nmain=window.nmain||{},window.nmain&&(window.nmain.cdnFallbackLogQueue=[]);function r(e){try{if(!window.nmain)return;if(Math.random()>=.01)return;var n=new Error(e);window.nmain.sendInfo?window.nmain.sendInfo(n):window.nmain.cdnFallbackLogQueue&&window.nmain.cdnFallbackLogQueue.push(n)}catch(e){}}function a(e,r){const a=new URL(e),c=n[a.hostname];if(!c)return e;if(-1!==t.indexOf(a.hostname))return a.hostname=c,a.toString();if(e.includes(".cdnfallback."))return e;a.hostname=c;const s=new RegExp(`\\.(${r})$`,"i");return a.pathname=a.pathname.replace(s,".cdnfallback.$1"),a.toString()}window.addEventListener("error",t=>{const{target:c}=t;if(e)if(c.dataset&&"done"===c.dataset.cdnFallbackAttempt)c instanceof HTMLImageElement?r("[CDN Fallback] fallback img resource load failed: "+c.src):c instanceof HTMLLinkElement?r("[CDN Fallback] fallback css resource load failed: "+c.href):c instanceof HTMLScriptElement&&r("[CDN Fallback] fallback js resource load failed: "+c.src);else if(c instanceof HTMLImageElement){var s=c.src;(function(e,t){if(!e.src)return!1;const r=new URL(e.src),a=n[r.hostname];if(!a)return!1;t.stopImmediatePropagation(),t.preventDefault();var c=r.hostname;if(r.hostname=a,e.src=r.toString(),e.srcset&&(e.srcset=e.srcset.split("//"+c).join("//"+a)),e.parentElement&&e.parentElement instanceof HTMLPictureElement)for(var s=e.parentElement.querySelectorAll("source"),o=0;o<s.length;o++){var i=s[o];i.srcset&&Object.keys(n).forEach(function(e){i.srcset=i.srcset.split("//"+e).join("//"+n[e])})}return e.dataset.cdnFallbackAttempt="done",!0})(c,t)&&r("[CDN Fallback] origin img resource load failed: "+s)}else c instanceof HTMLLinkElement?function(e){if(!e.href||"done"===e.dataset.cdnFallbackAttempt)return!1;const n=a(e.href,"css");if(n!==e.href){const t=document.createElement("link");return t.rel="stylesheet",t.href=n,t.dataset.cdnFallbackAttempt="done",e.onerror&&(t.onerror=e.onerror),e.type&&(t.type=e.type),e.media&&(t.media=e.media),e.parentNode&&e.parentNode.insertBefore(t,e.nextSibling),!0}return!1}(c)&&r("[CDN Fallback] origin css resource load failed: "+c.href):c instanceof HTMLScriptElement&&function(e){if(!e.src||"done"===e.dataset.cdnFallbackAttempt)return!1;const n=a(e.src,"js");if(n!==e.src){const t=document.createElement("script");return t.src=n,t.crossOrigin=e.crossOrigin,t.async=e.async,t.defer=e.defer,t.dataset.cdnFallbackAttempt="done",e.onerror&&(t.onerror=e.onerror),e.type&&(t.type=e.type),e.parentNode&&e.parentNode.insertBefore(t,e.nextSibling),!0}return!1}(c)&&r("[CDN Fallback] origin js resource load failed: "+c.src)},{capture:!0})}()</script> <script defer="defer" src="https://pm.pstatic.net/resources/js/polyfill.9d57c570.js?o=www" crossorigin="anonymous"></script><script defer="defer" src="https://pm.pstatic.net/resources/js/preload.7ebb5d79.js?o=www" crossorigin="anonymous"></script><script defer="defer" src="https://pm.pstatic.net/resources/js/search.ff8beebc.js?o=www" crossorigin="anonymous"></script><script defer="defer" src="https://pm.pstatic.net/resources/js/main.fdb73099.js?o=www" crossorigin="anonymous"></script><link href="https://pm.pstatic.net/resources/css/main.4f099899.css" rel="stylesheet"></head> <body> <div id="u_skip"> <a href="#topAsideButton"><span>상단영역 바로가기</span></a> <a href="#shortcutArea"><span>서비스 메뉴 바로가기</span></a> <a href="#newsstand"><span>새소식 블록 바로가기</span></a> <a href="#shopping"><span>쇼핑 블록 바로가기</span></a> <a href="#feed"><span>관심사 블록 바로가기</span></a> <a href="#account"><span>MY 영역 바로가기</span></a> <a href="#widgetboard"><span>위젯 보드 바로가기</span></a> <a href="#viewSetting"><span>보기 설정 바로가기</span></a> </div>   <script type="text/plain" id="ad-timeboard-response" data-gfp-banner-size="1444x150" data-gfp-banner-type="full">{"payload":{"requestI ...
# </script> <div id="wrap"> <div id="whale-banner"></div> <div id="whale-banner-bottom"></div> <div id="header" role="banner"> <div id="topSearchWrap" class="header_inner"> <div id="special-logo" class="search_special_bg"></div> <div id="timeboard-ex" class="ad_area" style="width:1280px"> </div> <div id="search_area" class="search_area" style="border-color:#fff"> <div class="search_group"> <div id="search" class="search_group_inner"> <h1 id="special-input-logo" class="search_logo"></h1> <form id="sform" name="search" role="search" action="https://search.naver.com/search.naver" method="get"> <fieldset> <legend class="blind">검색</legend> <input type="hidden" name="where" value="nexearch"/> <input type="hidden" id="sm" name="sm" value="top_hty"/> <input type="hidden" id="fbm" name="fbm" value="0"/> <input type="hidden" id="acr" name="acr" value="" disabled="disabled"/> <input type="hidden" id="acq" name="acq" value="" disabled="disabled"/> <input type="hidden" id="qdt" name="qdt" value="" disabled="disabled"/> <input type="hidden" id="ie" name="ie" value="utf8"/> <input type="hidden" id="acir" name="acir" value="" disabled="disabled"/> <input type="hidden" id="os" name="os" value="" disabled="disabled"/> <input type="hidden" id="bid" name="bid" value="" disabled="disabled"/> <input type="hidden" id="pkid" name="pkid" value="" disabled="disabled"/> <input type="hidden" id="eid" name="eid" value="" disabled="disabled"/> <input type="hidden" id="mra" name="mra" value="" disabled="disabled"/> <div class="search_input_box"> <input id="query" type="search" name="query" class="search_input" maxlength="255" autocomplete="off" placeholder="검색어를 입력해 주세요." title="검색어를 입력해 주세요." role="combobox" aria-expanded="false" aria-haspopup="listbox" aria-owns="autoFrame" aria-controls="" aria-autocomplete="list" aria-activedescendant="" data-atcmp-element=""> </div> <button id="search-btn" type="submit" class="btn_search" style="display:none" onclick='window.ntm.push({event:"nclick",el:this,click_area:"sch.action"})'> <span class="ico_btn_search_svg"> <svg id="search-btn-svg" viewBox="0 0 50 50" xmlns="http://www.w3.org/2000/svg"> <path d="M22.13.5c11.378 0 20.632 9.256 20.632 20.63 0 4.699-1.566 9.155-4.439 12.782l10.164 10.165a2.41 2.41 0 0 1-1.706 4.115 2.412 2.412 0 0 1-1.706-.705L33.31 35.719a2.41 2.41 0 0 1 0-3.41 15.71 15.71 0 0 0 4.628-11.178c0-8.718-7.09-15.808-15.807-15.808-8.718 0-15.808 7.09-15.808 15.808 0 7.15 4.817 13.43 11.714 15.273a2.41 2.41 0 0 1 1.705 2.954 2.41 2.41 0 0 1-2.95 1.705C7.788 38.658 1.5 30.46 1.5 21.131 1.5 9.756 10.756.5 22.13.5zm4.716 34.746a3.483 3.483 0 1 1 0 6.966 3.483 3.483 0 0 1 0-6.966z"/> </svg> </span> <span class="blind">검색</span> </button> <button id="search-ai-tab-button" type="submit" class="btn_ai_search type_effect"> <span id="search-ai-tab-button-inner" class="ai_effect_symbol"></span> <span class="blind">AI 검색</span> </button> </fieldset> </form> <div id="search-box" class="search_box" style="display:none"> <button id="ke_kbd_btn" type="button" class="btn_keyboard" aria-pressed="false"> <span class="blind">입력도구</span> </button> <div id="_nx_kbd" style="display:none"></div> </div> <div class="layer_atcmp" id="autoFrame" style="display:none"></div> </div> </div> </div> <div id="search-right"></div> <div id="shortcutArea" class="shortcut_area" role="navigation" aria-label="주요 서비스"></div> <div id="topAsideArea" class="menu_area"></div> <div id="topPayArea" class="pay_area"></div> <div id="topTalkArea" class="talk_area"></div> <div id="topNotiArea" class="notify_area"></div> <div id="topShoppingArea" class="shopping_area"></div> </div> </div> <div id="container" role="main"> <div id="ad_premium_area" class="ad_premium_area" style="min-width:1920px"> </div> <div id="root"></div> </div> <div id="footer" role="contentinfo"></div> </div>      <script> window['EAGER-DATA'] = window['EAGER-DATA'] || {};
#         window['EAGER-DATA']['GV'] = {
#             svt: '20260723122721',  }; </script> <script>!function(){function t(t){var e=document.getElementById("search_area"),i=document.getElementById("search-btn-svg");if(!t)return e&&e.removeAttribute("style"),void(i&&i.setAttribute("style","fill: #03c75a"));e&&e.setAttribute("style","border-color: "+t),i&&i.setAttribute("class","ico_btn_search type_color"),i&&i.setAttribute("style","fill: "+t)}var e=function(){if(!window["EAGER-DATA"].GV.isBirthday)return null;const t=window["EAGER-DATA"].GV.svt;return/^[0-9]{4}(06|07|08)/.test(t)?{logo:{image:"https://s.pstatic.net/static/www/mobile/edit/20260618_0/upload_1781759196263kNOzt.gif",imageDark:"https://s.pstatic.net/static/www/mobile/edit/20260618_0/upload_1781759205103f3Tr8.gif",textColor:"#0E9FF2"},input:{showSearchLogo:!0,color:"#0E9FF2",logoImage:"https://s.pstatic.net/static/www/mobile/edit/20260406_0/pc.summer.n.png"}}:/^[0-9]{4}(09|10|11)/.test(t)?{logo:{image:"https://s.pstatic.net/static/www/mobile/edit/20250828_0/pc_birth_9_10_11.gif",imageDark:"https://s.pstatic.net/static/www/mobile/edit/20250918_0/pc_birth_9_10_11_dark.gif",textColor:"#FF6700"},input:{showSearchLogo:!0,color:"#FF6700",logoImage:"https://s.pstatic.net/static/www/mobile/edit/20260406_0/pc.fall.n.png"}}:/^[0-9]{4}(12|01|02)/.test(t)?{logo:{image:"https://s.pstatic.net/static/www/mobile/edit/20251209_0/pc_birth_12_1_2.gif",imageDark:"https://s.pstatic.net/static/www/mobile/edit/20251209_0/pc_birth_12_1_2_dark.gif",textColor:"#895bd2"},input:{showSearchLogo:!0,color:"#895bd2",logoImage:"https://s.pstatic.net/static/www/mobile/edit/20260406_0/pc.winter.n.png"}}:/^[0-9]{4}(03|04|05)/.test(t)?{logo:{image:"https://s.pstatic.net/static/www/mobile/edit/20260406_0/spring.gif",imageDark:"https://s.pstatic.net/static/www/mobile/edit/20260406_0/spring.dark.gif",textColor:"#f86391"},input:{showSearchLogo:!0,color:"#f86391",logoImage:"https://s.pstatic.net/static/www/mobile/edit/20260406_0/pc.spring.n.png"}}:null}(),i=window["EAGER-DATA"]["CAS-MINICONTENT-PC-SPECIAL-LOGO"];if(!(e||i&&i.items&&i.items.length>0!=!1))return void t();const o=!e&&i.items[0]?.content?.logo?.isWedding?{logo:{image:"https://s.pstatic.net/static/www/mobile/edit/20260406_0/pc.wedding.gif",imageDark:"https://s.pstatic.net/static/www/mobile/edit/20260406_0/pc.wedding.dark.gif",textColor:"#0091F3",textColorDark:"#3AAFFE",isWedding:!0},input:{color:"#3AAFFE"}}:null;var s=function(){if(e){const t=e;return Object.assign(t.logo,{alt:"생일 축하 합니다.",top:0,left:0,clickAreaList:[{left:0,top:0,height:240,width:639,url:"https://mkt.naver.com/p1/atrb?channel_id=naver_pcspeciallogo&campaign_id=2311-logo-001&target=https%3A%2F%2Fnaver.me%2FxguXFZwP%3Fdtm_source%3Dnaver_pcspeciallogo%26dtm_medium%3Dmktatrb_mn%26dtm_campaign%3D2311-logo-001",alt:"생일 축하 합니다.",clickCode:"top.hbdlogo"}],isBirthday:!0}),{content:t}}if(o)return{content:o};var t=Math.floor(Math.random()*i.items.length);return i.items[t]}();i.items=[s];const a=s&&s.content?s.content.input:null;t(a&&a.color);const n=document.getElementById("search"),c=n&&(!a||!a.showSearchLogo);c&&n.classList.add("type_special_logo_full"),window.addEventListener("header-sticky-state-change",function(){var t;(t=document.getElementById("header"))&&t.classList.contains("ani_fixed")?c&&n.classList.remove("type_special_logo_full"):c&&n.classList.add("type_special_logo_full")});var l=a&&a.placeholder;if(l){var r=document.getElementById("query");r&&l&&r.setAttribute("title",l),r&&l&&r.setAttribute("placeholder",l)}}()</script> </body> </html>
# <class 'str'>

# %%
# BeautifulSoup(parsing 할 데이터, parsing 방법)

bs_obj2 = bs4.BeautifulSoup(res.text, 'html.parser')

print(type(bs_obj2))
print(dir(bs_obj2))
print(bs_obj2.find('div')) # 최초로 검색되는 div 하나만 가져온다
print(type(bs_obj2.find('div'))) # class 'bs4.element.Tag
print(bs_obj2.find_all('div'))
print(type(bs_obj2.find_all('div'))) # class 'bs4.ResultSet
print("-----------------------------")
print(bs_obj2.find('xk')) # 결과값이 없을 경우 None으로 리턴한다.
print(bs_obj2.find_all('xk')) # 결과값이 없을 경우 []으로 리턴한다.
# Out:
# <class 'bs4.BeautifulSoup'>
# ['ASCII_SPACES', 'DEFAULT_BUILDER_FEATURES', 'EMPTY_ELEMENT_EVENT', 'END_ELEMENT_EVENT', 'MAIN_CONTENT_STRING_TYPES', 'ROOT_TAG_NAME', 'START_ELEMENT_EVENT', 'STRING_ELEMENT_EVENT', '_TreeTraversalEvent', '__annotations__', '__bool__', '__call__', '__class__', '__contains__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__unicode__', '__weakref__', '_all_strings', '_decode_markup', '_event_stream', '_feed', '_find_all', '_find_one', '_format_tag', '_generator_for_recursive', '_indent_string', '_insert', '_is_root', '_is_xml', '_lastRecursiveChild', '_last_descendant', '_linkage_fixer', '_markup_is_url', '_markup_resembles_filename', '_most_recent_element', '_namespaces', '_popToTag', '_root_object', '_self_and', '_should_pretty_print', '_warning_stack_level', 'append', 'attribute_value_list_class', 'attrs', 'builder', 'can_be_empty_element', 'cdata_list_attributes', 'childGenerator', 'children', 'clear', 'contains_replacement_characters', 'contents', 'copy_self', 'css', 'currentTag', 'current_data', 'declared_html_encoding', 'decode', 'decode_contents', 'decompose', 'decomposed', 'default', 'descendants', 'element_classes', 'encode', 'encode_contents', 'endData', 'extend', 'extract', 'fetchAllPrevious', 'fetchNextSiblings', 'fetchParents', 'fetchPreviousSiblings', 'find', 'findAll', 'findAllNext', 'findAllPrevious', 'findChild', 'findChildren', 'findNext', 'findNextSibling', 'findNextSiblings', 'findParent', 'findParents', 'findPrevious', 'findPreviousSibling', 'findPreviousSiblings', 'find_all', 'find_all_next', 'find_all_previous', 'find_next', 'find_next_sibling', 'find_next_siblings', 'find_parent', 'find_parents', 'find_previous', 'find_previous_sibling', 'find_previous_siblings', 'format_string', 'formatter_for_name', 'get', 'getText', 'get_attribute_list', 'get_text', 'handle_data', 'handle_endtag', 'handle_starttag', 'has_attr', 'has_key', 'hidden', 'index', 'insert', 'insert_after', 'insert_before', 'interesting_string_types', 'isSelfClosing', 'is_empty_element', 'is_xml', 'known_xml', 'markup', 'name', 'namespace', 'new_string', 'new_tag', 'next', 'nextGenerator', 'nextSibling', 'nextSiblingGenerator', 'next_element', 'next_elements', 'next_sibling', 'next_siblings', 'object_was_parsed', 'open_tag_counter', 'original_encoding', 'parent', 'parentGenerator', 'parents', 'parse_only', 'parserClass', 'parser_class', 'popTag', 'prefix', 'preserve_whitespace_tag_stack', 'preserve_whitespace_tags', 'prettify', 'previous', 'previousGenerator', 'previousSibling', 'previousSiblingGenerator', 'previous_element', 'previous_elements', 'previous_sibling', 'previous_siblings', 'pushTag', 'recursiveChildGenerator', 'renderContents', 'replaceWith', 'replaceWithChildren', 'replace_with', 'replace_with_children', 'reset', 'select', 'select_one', 'self_and_descendants', 'self_and_next_elements', 'self_and_next_siblings', 'self_and_parents', 'self_and_previous_elements', 'self_and_previous_siblings', 'setup', 'smooth', 'sourceline', 'sourcepos', 'string', 'string_container', 'string_container_stack', 'strings', 'stripped_strings', 'tagStack', 'text', 'unwrap', 'wrap']
# <div id="u_skip"> <a href="#topAsideButton"><span>상단영역 바로가기</span></a> <a href="#shortcutArea"><span>서비스 메뉴 바로가기</span></a> <a href="#newsstand"><span>새소식 블록 바로가기</span></a> <a href="#shopping"><span>쇼핑 블록 바로가기</span></a> <a href="#feed"><span>관심사 블록 바로가기</span></a> <a href="#account"><span>MY 영역 바로가기</span></a> <a href="#widgetboard"><span>위젯 보드 바로가기</span></a> <a href="#viewSetting"><span>보기 설정 바로가기</span></a> </div>
# <class 'bs4.element.Tag'>
# [<div id="u_skip"> <a href="#topAsideButton"><span>상단영역 바로가기</span></a> <a href="#shortcutArea"><span>서비스 메뉴 바로가기</span></a> <a href="#newsstand"><span>새소식 블록 바로가기</span></a> <a href="#shopping"><span>쇼핑 블록 바로가기</span></a> <a href="#feed"><span>관심사 블록 바로가기</span></a> <a href="#account"><span>MY 영역 바로가기</span></a> <a href="#widgetboard"><span>위젯 보드 바로가기</span></a> <a href="#viewSetting"><span>보기 설정 바로가기</span></a> </div>, <div id="wrap"> <div id="whale-banner"></div> <div id="whale-banner-bottom"></div> <div id="header" role="banner"> <div class="header_inner" id="topSearchWrap"> <div class="search_special_bg" id="special-logo"></div> <div class="ad_area" id="timeboard-ex" style="width:1280px"> </div> <div class="search_area" id="search_area" style="border-color:#fff"> <div class="search_group"> <div class="search_group_inner" id="search"> <h1 class="search_logo" id="special-input-logo"></h1> <form action="https://search.naver.com/search.naver" id="sform" method="get" name="search" role="search"> <fieldset> <legend class="blind">검색</legend> <input name="where" type="hidden" value="nexearch"/> <input id="sm" name="sm" type="hidden" value="top_hty"/> <input id="fbm" name="fbm" type="hidden" value="0"/> <input disabled="disabled" id="acr" name="acr" type="hidden" value=""/> <input disabled="disabled" id="acq" name="acq" type="hidden" value=""/> <input disabled="disabled" id="qdt" name="qdt" type="hidden" value=""/> <input id="ie" name="ie" type="hidden" value="utf8"/> <input disabled="disabled" id="acir" name="acir" type="hidden" value=""/> <input disabled="disabled" id="os" name="os" type="hidden" value=""/> <input disabled="disabled" id="bid" name="bid" type="hidden" value=""/> <input disabled="disabled" id="pkid" name="pkid" type="hidden" value=""/> <input disabled="disabled" id="eid" name="eid" type="hidden" value=""/> <input disabled="disabled" id="mra" name="mra" type="hidden" value=""/> <div class="search_input_box"> <input aria-activedescendant="" aria-autocomplete="list" aria-controls="" aria-expanded="false" aria-haspopup="listbox" aria-owns="autoFrame" autocomplete="off" class="search_input" data-atcmp-element="" id="query" maxlength="255" name="query" placeholder="검색어를 입력해 주세요." role="combobox" title="검색어를 입력해 주세요." type="search"/> </div> <button class="btn_search" id="search-btn" onclick='window.ntm.push({event:"nclick",el:this,click_area:"sch.action"})' style="display:none" type="submit"> <span class="ico_btn_search_svg"> <svg id="search-btn-svg" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg"> <path d="M22.13.5c11.378 0 20.632 9.256 20.632 20.63 0 4.699-1.566 9.155-4.439 12.782l10.164 10.165a2.41 2.41 0 0 1-1.706 4.115 2.412 2.412 0 0 1-1.706-.705L33.31 35.719a2.41 2.41 0 0 1 0-3.41 15.71 15.71 0 0 0 4.628-11.178c0-8.718-7.09-15.808-15.807-15.808-8.718 0-15.808 7.09-15.808 15.808 0 7.15 4.817 13.43 11.714 15.273a2.41 2.41 0 0 1 1.705 2.954 2.41 2.41 0 0 1-2.95 1.705C7.788 38.658 1.5 30.46 1.5 21.131 1.5 9.756 10.756.5 22.13.5zm4.716 34.746a3.483 3.483 0 1 1 0 6.966 3.483 3.483 0 0 1 0-6.966z"></path> </svg> </span> <span class="blind">검색</span> </button> <button class="btn_ai_search type_effect" id="search-ai-tab-button" type="submit"> <span class="ai_effect_symbol" id="search-ai-tab-button-inner"></span> <span class="blind">AI 검색</span> </button> </fieldset> </form> <div class="search_box" id="search-box" style="display:none"> <button aria-pressed="false" class="btn_keyboard" id="ke_kbd_btn" type="button"> <span class="blind">입력도구</span> </button> <div id="_nx_kbd" style="display:none"></div> </div> <div class="layer_atcmp" id="autoFrame" style="display:none"></div> </div> </div> </div> <div id="search-right"></div> <div aria-label="주요 서비스" class="shortcut_area" id="shortcutArea" role="navigation"></div> <div class="menu_area" id="topAsideArea"></div> <div class="pay_area" id="topPayArea"></div> <div class="talk_area" id="topTalkArea"></div> <div class="notify_area" id="topNotiArea"></div> <div class="shoppi ...
# <class 'bs4.element.ResultSet'>
# -----------------------------
# None
# []

# %%
html_str = """
<!DOCTYPE html>
<html>
    <body>
        <ul class="ko">
            <li>
                <p> Previous Element1</p>
                <p> Previous Element2</p>
                <a  href ="https://www.naver.com"> 네이버</a>
                <p> Next Element1</p>
                <p> Next Element2</p>
            </li>

            <li>
                <a  href ="https://www.daum.net"> 다음</a>
            </li>
        </ul>

        <ul class="sns">
            <li>
                <a href="https://www.google.com">구글</a>
            </li>
            <li>
                <a href="https://www.facebook.com">페이스북</a>
            </li>
        </ul>
        <div id="result"></div>
    </body>
</html>
"""

# %%
import bs4

bs_obj = bs4.BeautifulSoup(html_str, 'html.parser')

# %% [markdown]
# ## find()

# %%
print(type(bs_obj))
print(dir(bs_obj))
# Out:
# <class 'bs4.BeautifulSoup'>
# ['ASCII_SPACES', 'DEFAULT_BUILDER_FEATURES', 'EMPTY_ELEMENT_EVENT', 'END_ELEMENT_EVENT', 'MAIN_CONTENT_STRING_TYPES', 'ROOT_TAG_NAME', 'START_ELEMENT_EVENT', 'STRING_ELEMENT_EVENT', '_TreeTraversalEvent', '__annotations__', '__bool__', '__call__', '__class__', '__contains__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__unicode__', '__weakref__', '_all_strings', '_decode_markup', '_event_stream', '_feed', '_find_all', '_find_one', '_format_tag', '_generator_for_recursive', '_indent_string', '_insert', '_is_root', '_is_xml', '_lastRecursiveChild', '_last_descendant', '_linkage_fixer', '_markup_is_url', '_markup_resembles_filename', '_most_recent_element', '_namespaces', '_popToTag', '_root_object', '_self_and', '_should_pretty_print', '_warning_stack_level', 'append', 'attribute_value_list_class', 'attrs', 'builder', 'can_be_empty_element', 'cdata_list_attributes', 'childGenerator', 'children', 'clear', 'contains_replacement_characters', 'contents', 'copy_self', 'css', 'currentTag', 'current_data', 'declared_html_encoding', 'decode', 'decode_contents', 'decompose', 'decomposed', 'default', 'descendants', 'element_classes', 'encode', 'encode_contents', 'endData', 'extend', 'extract', 'fetchAllPrevious', 'fetchNextSiblings', 'fetchParents', 'fetchPreviousSiblings', 'find', 'findAll', 'findAllNext', 'findAllPrevious', 'findChild', 'findChildren', 'findNext', 'findNextSibling', 'findNextSiblings', 'findParent', 'findParents', 'findPrevious', 'findPreviousSibling', 'findPreviousSiblings', 'find_all', 'find_all_next', 'find_all_previous', 'find_next', 'find_next_sibling', 'find_next_siblings', 'find_parent', 'find_parents', 'find_previous', 'find_previous_sibling', 'find_previous_siblings', 'format_string', 'formatter_for_name', 'get', 'getText', 'get_attribute_list', 'get_text', 'handle_data', 'handle_endtag', 'handle_starttag', 'has_attr', 'has_key', 'hidden', 'index', 'insert', 'insert_after', 'insert_before', 'interesting_string_types', 'isSelfClosing', 'is_empty_element', 'is_xml', 'known_xml', 'markup', 'name', 'namespace', 'new_string', 'new_tag', 'next', 'nextGenerator', 'nextSibling', 'nextSiblingGenerator', 'next_element', 'next_elements', 'next_sibling', 'next_siblings', 'object_was_parsed', 'open_tag_counter', 'original_encoding', 'parent', 'parentGenerator', 'parents', 'parse_only', 'parserClass', 'parser_class', 'popTag', 'prefix', 'preserve_whitespace_tag_stack', 'preserve_whitespace_tags', 'prettify', 'previous', 'previousGenerator', 'previousSibling', 'previousSiblingGenerator', 'previous_element', 'previous_elements', 'previous_sibling', 'previous_siblings', 'pushTag', 'recursiveChildGenerator', 'renderContents', 'replaceWith', 'replaceWithChildren', 'replace_with', 'replace_with_children', 'reset', 'select', 'select_one', 'self_and_descendants', 'self_and_next_elements', 'self_and_next_siblings', 'self_and_parents', 'self_and_previous_elements', 'self_and_previous_siblings', 'setup', 'smooth', 'sourceline', 'sourcepos', 'string', 'string_container', 'string_container_stack', 'strings', 'stripped_strings', 'tagStack', 'text', 'unwrap', 'wrap']

# %%
print(bs_obj.find("div"))
print(type(bs_obj.find("div")))
print(dir(bs_obj.find("div")))

# text 는 태그 내부의 텍스트와 모든 자식 태그의 텍스트를 포함하여 반환하는 반면, string 은 해당 태그 바로 아래의 텍스트만 반환
print(bs_obj.find("div").text)
print(bs_obj.find("div").string)
# Out:
# <div id="result"></div>
# <class 'bs4.element.Tag'>
# ['EMPTY_ELEMENT_EVENT', 'END_ELEMENT_EVENT', 'MAIN_CONTENT_STRING_TYPES', 'START_ELEMENT_EVENT', 'STRING_ELEMENT_EVENT', '_TreeTraversalEvent', '__annotations__', '__bool__', '__call__', '__class__', '__contains__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', '__unicode__', '__weakref__', '_all_strings', '_event_stream', '_find_all', '_find_one', '_format_tag', '_generator_for_recursive', '_indent_string', '_insert', '_is_root', '_is_xml', '_lastRecursiveChild', '_last_descendant', '_namespaces', '_root_object', '_self_and', '_should_pretty_print', '_warning_stack_level', 'append', 'attribute_value_list_class', 'attrs', 'can_be_empty_element', 'cdata_list_attributes', 'childGenerator', 'children', 'clear', 'contents', 'copy_self', 'css', 'decode', 'decode_contents', 'decompose', 'decomposed', 'default', 'descendants', 'encode', 'encode_contents', 'extend', 'extract', 'fetchAllPrevious', 'fetchNextSiblings', 'fetchParents', 'fetchPreviousSiblings', 'find', 'findAll', 'findAllNext', 'findAllPrevious', 'findChild', 'findChildren', 'findNext', 'findNextSibling', 'findNextSiblings', 'findParent', 'findParents', 'findPrevious', 'findPreviousSibling', 'findPreviousSiblings', 'find_all', 'find_all_next', 'find_all_previous', 'find_next', 'find_next_sibling', 'find_next_siblings', 'find_parent', 'find_parents', 'find_previous', 'find_previous_sibling', 'find_previous_siblings', 'format_string', 'formatter_for_name', 'get', 'getText', 'get_attribute_list', 'get_text', 'has_attr', 'has_key', 'hidden', 'index', 'insert', 'insert_after', 'insert_before', 'interesting_string_types', 'isSelfClosing', 'is_empty_element', 'known_xml', 'name', 'namespace', 'new_string', 'new_tag', 'next', 'nextGenerator', 'nextSibling', 'nextSiblingGenerator', 'next_element', 'next_elements', 'next_sibling', 'next_siblings', 'parent', 'parentGenerator', 'parents', 'parserClass', 'parser_class', 'prefix', 'preserve_whitespace_tags', 'prettify', 'previous', 'previousGenerator', 'previousSibling', 'previousSiblingGenerator', 'previous_element', 'previous_elements', 'previous_sibling', 'previous_siblings', 'recursiveChildGenerator', 'renderContents', 'replaceWith', 'replaceWithChildren', 'replace_with', 'replace_with_children', 'select', 'select_one', 'self_and_descendants', 'self_and_next_elements', 'self_and_next_siblings', 'self_and_parents', 'self_and_previous_elements', 'self_and_previous_siblings', 'setup', 'smooth', 'sourceline', 'sourcepos', 'string', 'strings', 'stripped_strings', 'text', 'unwrap', 'wrap']
#
# None

# %%
ulEle = bs_obj.find("ul")
print(ulEle)
# Out:
# <ul class="ko">
# <li>
# <p> Previous Element1</p>
# <p> Previous Element2</p>
# <a href="https://www.naver.com"> 네이버</a>
# <p> Next Element1</p>
# <p> Next Element2</p>
# </li>
# <li>
# <a href="https://www.daum.net"> 다음</a>
# </li>
# </ul>

# %%
ul_li = ulEle.find("li")
print(ul_li)
print(type(ul_li))
# Out:
# <li>
# <p> Previous Element1</p>
# <p> Previous Element2</p>
# <a href="https://www.naver.com"> 네이버</a>
# <p> Next Element1</p>
# <p> Next Element2</p>
# </li>
# <class 'bs4.element.Tag'>

# %%
print(ul_li.text)
print(ul_li.string)
# Out:
#  Previous Element1
#  Previous Element2
#  네이버
#  Next Element1
#  Next Element2
#
# None

# %% [markdown]
# #### find_all()
# - 주어진 기준에 맞는 모든 태그들을 가져옴
# - 결과는 bs4.element.ReseltSet 객체로 리턴
# - 호출 방법
#   - find_all('div')
#   - find_all(['p', 'img'])
#   - find_all(True)
#   - find_all(re.compile('b'))
#   - find_all(id='link')
#   - find_all(src=re.compile('png$'), id='fid')
#   - find_all('a', limit=2)

# %%
ul = bs_obj.find("ul")
ul_li = ul.find_all("li")

print(ul_li)
print("-------------------")
print(ul_li[0])
print("-------------------")
print(ul_li[1])
# Out:
# [<li>
# <p> Previous Element1</p>
# <p> Previous Element2</p>
# <a href="https://www.naver.com"> 네이버</a>
# <p> Next Element1</p>
# <p> Next Element2</p>
# </li>, <li>
# <a href="https://www.daum.net"> 다음</a>
# </li>]
# -------------------
# <li>
# <p> Previous Element1</p>
# <p> Previous Element2</p>
# <a href="https://www.naver.com"> 네이버</a>
# <p> Next Element1</p>
# <p> Next Element2</p>
# </li>
# -------------------
# <li>
# <a href="https://www.daum.net"> 다음</a>
# </li>

# %%
for element in ul_li:
    print(element.text)
    print("=====================")
# Out:
#  Previous Element1
#  Previous Element2
#  네이버
#  Next Element1
#  Next Element2
#
# =====================
#
#  다음
#
# =====================

# %%
for element in ul_li:
    print(element.string)
    print("=====================")
# Out:
# None
# =====================
# None
# =====================

# %% [markdown]
# ## class 속성 이용하기 : tag_and_property

# %%
ul_reply = bs_obj.find("ul")
ul_ko = bs_obj.find("ul", {"class" : "ko"}) # ul 엘리먼트의 class 속성의 값이 'ko'인것만 가져온다
ul_ko = bs_obj.find("ul", class_="ko") # class_로 표기하여 사용 가능

print(ul_ko)
# Out:
# <ul class="ko">
# <li>
# <p> Previous Element1</p>
# <p> Previous Element2</p>
# <a href="https://www.naver.com"> 네이버</a>
# <p> Next Element1</p>
# <p> Next Element2</p>
# </li>
# <li>
# <a href="https://www.daum.net"> 다음</a>
# </li>
# </ul>

# %%
ul_sns = bs_obj.find("ul", attrs={"class": "sns"}) # ul 엘리먼트 class 속성의 값이 'sns'일 때 가져온다
print(ul_sns)
# Out:
# <ul class="sns">
# <li>
# <a href="https://www.google.com">구글</a>
# </li>
# <li>
# <a href="https://www.facebook.com">페이스북</a>
# </li>
# </ul>

# %%
ul_li = bs_obj.find("ul", attrs={"class" : "sns"}).find("li")
print(ul_li)
# Out:
# <li>
# <a href="https://www.google.com">구글</a>
# </li>

# %%
ul_li = bs_obj.find("ul", attrs={"class" : "sns"}).find_all("li")
print(ul_li)
# Out:
# [<li>
# <a href="https://www.google.com">구글</a>
# </li>, <li>
# <a href="https://www.facebook.com">페이스북</a>
# </li>]

# %%
for element in ul_li:
    print(element.text)
    print("===========")
# Out:
# 구글
#
# ===========
#
# 페이스북
#
# ===========

# %% [markdown]
# #### 속성값 가져오기 property_href

# %%
atag = bs_obj.find("a")
print(atag)
# Out:
# <a href="https://www.naver.com"> 네이버</a>

# %%
print(atag["href"])
print(type(atag["href"]))
# Out:
# https://www.naver.com
# <class 'str'>

# %%
atag = bs_obj.find_all("a")
print(atag)
print(len(atag))
# Out:
# [<a href="https://www.naver.com"> 네이버</a>, <a href="https://www.daum.net"> 다음</a>, <a href="https://www.google.com">구글</a>, <a href="https://www.facebook.com">페이스북</a>]
# 4

# %%
for attr in atag:
    print(attr["href"])
# Out:
# https://www.naver.com
# https://www.daum.net
# https://www.google.com
# https://www.facebook.com

# %%
print(bs_obj.find("a").attrs)
print(type(bs_obj.find("a").attrs))
# Out:
# {'href': 'https://www.naver.com'}
# <class 'bs4.element.AttributeDict'>

# %%
# id 속성의 값이 "result" 인 태그를 가져온다.

dv = bs_obj.find(id = "result")

print(dv)
print(type(dv))
# Out:
# <div id="result"></div>
# <class 'bs4.element.Tag'>

# %%
uclass = bs_obj.find(class_="ko")
print(uclass)

print("====================================")

uclass = bs_obj.find(True, {"class" : "ko"}) # 아무 태그나 상관없고 className이 ko인 태그 찾기
print(uclass)

print("====================================")

uclass = bs_obj.find(False, {"class" : "ko"}) # 태그 이름이 False인 태그 찾기 => 그런 태그는 없기 때문에 None
print(uclass)
# Out:
# <ul class="ko">
# <li>
# <p> Previous Element1</p>
# <p> Previous Element2</p>
# <a href="https://www.naver.com"> 네이버</a>
# <p> Next Element1</p>
# <p> Next Element2</p>
# </li>
# <li>
# <a href="https://www.daum.net"> 다음</a>
# </li>
# </ul>
# ====================================
# <ul class="ko">
# <li>
# <p> Previous Element1</p>
# <p> Previous Element2</p>
# <a href="https://www.naver.com"> 네이버</a>
# <p> Next Element1</p>
# <p> Next Element2</p>
# </li>
# <li>
# <a href="https://www.daum.net"> 다음</a>
# </li>
# </ul>
# ====================================
# None

# %%
print(bs_obj.find('a'))
print(bs_obj.a)

print(type(bs_obj.find('a')))       # bs4.element.Tag
print(type(bs_obj.a))               # bs4.element.Tag

print(bs_obj.find('a').get_text())
print(bs_obj.find('a').text)

print(type(bs_obj.find('a').get_text()))   #str
print(type(bs_obj.find('a').text))         #str
# Out:
# <a href="https://www.naver.com"> 네이버</a>
# <a href="https://www.naver.com"> 네이버</a>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
#  네이버
#  네이버
# <class 'str'>
# <class 'str'>

# %%
# attributes
print(bs_obj.attrs)
print(bs_obj.find('a').attrs)

print(bs_obj.a['href'])
print(bs_obj.a.attrs['href'])
print(bs_obj.a.get('href'))

print(bs_obj.find('a')['href'])
print(bs_obj.find('a').attrs['href'])
print(bs_obj.find('a').get('href'))
# Out:
# {}
# {'href': 'https://www.naver.com'}
# https://www.naver.com
# https://www.naver.com
# https://www.naver.com
# https://www.naver.com
# https://www.naver.com
# https://www.naver.com

# %%
#children
print(bs_obj.ul.children)
print(type(bs_obj.ul.children))

for sub in bs_obj.ul.children:
    print(sub)
# Out:
# <generator object Tag.children.<locals>.<genexpr> at 0x10c3e1f00>
# <class 'generator'>
#
#
# <li>
# <p> Previous Element1</p>
# <p> Previous Element2</p>
# <a href="https://www.naver.com"> 네이버</a>
# <p> Next Element1</p>
# <p> Next Element2</p>
# </li>
#
#
# <li>
# <a href="https://www.daum.net"> 다음</a>
# </li>

# %%
#sibling

print(bs_obj.find('a').next_siblings)       #generator object PageElement
ele = bs_obj.find('a').next_siblings
print(ele)

cnt = 0
for subNext in ele:
  cnt += 1
  print(subNext)

print('cnt', cnt)
# Out:
# <generator object PageElement.next_siblings at 0x10c5313c0>
# <generator object PageElement.next_siblings at 0x10c5313c0>
#
#
# <p> Next Element1</p>
#
#
# <p> Next Element2</p>
#
#
# cnt 5

# %%
ele = bs_obj.find("a").next_siblings

next(ele)
next(ele)
# Out:
# <p> Next Element1</p>

# %%
# 정규 표현식
import re

print(bs_obj.find('a', {'href':'https://www.naver.com'}))
print(bs_obj.find('a', {'href': re.compile('com$')}))              # com으로 끝나는
print(bs_obj.find('a', {'href': re.compile('.*naver.*')}))         # naver가 포함된
print(bs_obj.find('a', {'href': re.compile('naver')}))             # naver가 포함된
print(bs_obj.find('a', {'href': re.compile('^https')}))            # https으로 시작하는

print('-------------------------------------------')

print(bs_obj.find_all('a', {'href':'https://www.naver.com'}))
print(bs_obj.find_all('a', {'href': re.compile('com$')}))              # com으로 끝나는
print(bs_obj.find_all('a', {'href': re.compile('.*naver.*')}))         # naver가 포함된
print(bs_obj.find_all('a', {'href': re.compile('naver')}))             # naver가 포함된
print(bs_obj.find_all('a', {'href': re.compile('^https')}))            # https으로 시작하는

print('-------------------------------------------')

print("1", bs_obj.find(href='https://www.naver.com'))
print("2",bs_obj.find(href=lambda val : val))
print("3",bs_obj.find(href=lambda val : val and 'daum' in val))          # daum이 포함될때가지 검색을 함
print("4",bs_obj.find(class_=lambda val : val and 'sns' in val))        # class속성의 값이 sns가 포함되여 일때 가져온다.
# Out:
# <a href="https://www.naver.com"> 네이버</a>
# <a href="https://www.naver.com"> 네이버</a>
# <a href="https://www.naver.com"> 네이버</a>
# <a href="https://www.naver.com"> 네이버</a>
# <a href="https://www.naver.com"> 네이버</a>
# -------------------------------------------
# [<a href="https://www.naver.com"> 네이버</a>]
# [<a href="https://www.naver.com"> 네이버</a>, <a href="https://www.google.com">구글</a>, <a href="https://www.facebook.com">페이스북</a>]
# [<a href="https://www.naver.com"> 네이버</a>]
# [<a href="https://www.naver.com"> 네이버</a>]
# [<a href="https://www.naver.com"> 네이버</a>, <a href="https://www.daum.net"> 다음</a>, <a href="https://www.google.com">구글</a>, <a href="https://www.facebook.com">페이스북</a>]
# -------------------------------------------
# 1 <a href="https://www.naver.com"> 네이버</a>
# 2 <a href="https://www.naver.com"> 네이버</a>
# 3 <a href="https://www.daum.net"> 다음</a>
# 4 <ul class="sns">
# <li>
# <a href="https://www.google.com">구글</a>
# </li>
# <li>
# <a href="https://www.facebook.com">페이스북</a>
# </li>
# </ul>

# %% [markdown]
# #### select( ) vs select_one( )
# - 주어진 CSS 선택자에 맞는 모든 태그를 가져옴
# - 결과는 list객체로 리턴
# - CSS선택자를 적용한 호출
#   -  select('태그명')
#   -  select('.클래스명')
#   -  select('#아이디명')
#   -  select('태그명.클래스명')
#   -  select('상위태그명>자식태그명>손자태그명')
#   -  select('태그명:nth-of-type(2)')
#   -  select('태그명[속성]')
